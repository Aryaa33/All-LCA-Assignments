# %%
#Assignment 3: To check w
def right_triangle(a,b,c):
    if a*a + b*b == c*c:
        print("Right Angled Triangle")
    else:
        print("Not a right angled triangle")
right_triangle(3,4,5)
# Out:
# Right Angled Triangle
