# %%
a=int(input("Enter the first number:"))
b=int(input("Enter the second number:"))
c=int(input("Enter the third number:"))
if a==b==c:
    print("All three numbers are equal:",a)
elif a==b and a>c:
    print("largest number is:",a,b)
elif a==c and a>b:
    print("largest number is:",a,c)
elif b==c and b>a:
    print("largest number is:",b,c)
elif a>b and a.c:
    print("largest",a)
elif b>a and b>c:
    print("largest",b)
else:
    print("largest",c)
# Out:
# Enter the first number: 45
# Enter the second number: 78
# Enter the third number: 87
# largest 87
